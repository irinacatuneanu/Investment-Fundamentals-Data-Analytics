# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC','^GDAXI']

# %%
ind_data = pd.DataFrame()

# %%
for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo',start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %% [markdown]
# # Normalize to 100

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15,6))

# %%
ind_returns = (ind_data/ind_data.shift(1)) - 1
ind_returns.head()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 1997-01-02       NaN       NaN       NaN
# 1997-01-03  0.014952  0.023409  0.015049
# 1997-01-06 -0.000508  0.004364  0.009409
# 1997-01-07  0.007463  0.008607 -0.004795
# 1997-01-08 -0.006399 -0.005558  0.009644

# %%
annual_ind_returns = ind_returns.mean()*250

# %%
annual_ind_returns
# Out:
# ^GSPC     0.083605
# ^IXIC     0.122618
# ^GDAXI    0.078358
# dtype: float64

# %% [markdown]
# # Compare performance of stocks and stock indices

# %%
tickers = ['PG','^GSPC','^DJI']

# %%
data2 = pd.DataFrame()
for t in tickers:
    data2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2007-1-1')['Adj Close']

# %%
data2.head()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2007-01-03  42.872799  1416.599976  12474.519531
# 2007-01-04  42.547291  1418.339966  12480.690430
# 2007-01-05  42.181938  1409.709961  12398.009766
# 2007-01-08  42.274944  1412.839966  12423.490234
# 2007-01-09  42.168652  1412.109985  12416.599609

# %%
(data2 / data2.iloc[0] * 100).plot(figsize = (15,6))
